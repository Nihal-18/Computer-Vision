# %% [markdown]
# <a href="https://colab.research.google.com/github/Nihal-18/Computer-Vision/blob/main/Assignment_1_J058/Exp_2_Geometric_Transformation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# NAME: NIHAL M TODANKAR
#
# ROLL NO: J058
#
# BATCH: J3

# %% [markdown]
# #Exp 2:
# Perform geometric transformation operations such as:
#
# 1) Rotation
#
# 2) Scaling
#
# 3) Reflection
#
# 4) Dilation

# %%
import cv2
import matplotlib.pyplot as plt

# %%
from PIL import Image

# %%
im= Image.open('/content/drive/MyDrive/Unknown-2')

# %%
im
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=300x168 at 0x7F18483C1F90>

# %%
print(im.size)
# Out:
# (300, 168)

# %% [markdown]
# # Rotation

# %%
im_= im.rotate(angle= 180, expand= 10)

# %%
im_
# Out:
# <PIL.Image.Image image mode=RGB size=300x168 at 0x7F18482CAF10>

# %% [markdown]
# # Reflection

# %%
from PIL import ImageOps

# %%
im
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=300x168 at 0x7F18483C1F90>

# %%
im_flip= ImageOps.flip(im) # REflection along x - axis

# %%
im_flip

# %%
im_mirror= ImageOps.mirror(im) # Reflection along y - axis

im_mirror
# Out:
# <PIL.Image.Image image mode=RGB size=300x168 at 0x7FD047FC6A20>

# %% [markdown]
# # Scaling

# %%
im.size
# Out:
# (300, 168)

# %% [markdown]
# Shrinking

# %%
img= im.resize((200,150))

# %%
img
# Out:
# <PIL.Image.Image image mode=RGB size=200x150 at 0x7FC2F0B5CB70>

# %% [markdown]
# Zooming

# %%
img= im.resize((400,200))

# %%
img
# Out:
# <PIL.Image.Image image mode=RGB size=400x200 at 0x7FC2F0B54DA0>

# %% [markdown]
# # Cropping

# %%
im.size
# Out:
# (300, 168)

# %%
box= (20, 50, 190, 120)

# %%
cropped_image= im.crop(box= box)

cropped_image
# Out:
# <PIL.Image.Image image mode=RGB size=170x70 at 0x7FC2E75F2C18>
